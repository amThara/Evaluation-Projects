# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the basic libraries needed

# %%
data = pd.read_csv(r"C:\Users\Lenovo\Desktop\DS\Project\baseball.csv.txt")
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Open and read the data

# %% [markdown]
# ## Data Explanation
# - The problem statement consists of 16 indicators for success of a baseball game. This is a regression type of problem where we have to build a model to predict the number of wins using the labels.
# - The dataset is too small, so reduction of data should be avoided and it has to be standardised
# #### Target
# - W-Wins
# #### Labels
# - R-Runs
# - AB-At Bats
# - H-Hits
# - 2B-Doubles
# - 3B-Triples
# - HR-Homeruns
# - SO-Strikeouts
# - SB-Stolen Bases
# - RA-Runs Allowed
# - ER-Earned Runs
# - ERA-Earned Run Average
# - SHO-Shutouts
# - SV-Saves
# - CG-Complete Games
# - E-Errors
# - BB-Base on ball(Walk)

# %% [markdown]
# # Exploratory Data Analysis
# ### Identification of variables and data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Only ERA (Earned Run Average) is of type float. Others are integers. There is no NaN values present

# %%
data.shape
# Out:
# (30, 17)

# %% [markdown]
# Shape of the data set has 30 rows and 17 columns

# %% [markdown]
# ## Describing the data

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# There is no NaN values. Both the minimum and maximum values looks normal. Since all the columns is in integer/float, statistics for all columns is defined

# %% [markdown]
# ## Missing Value Treatment

# %%
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no missing value

# %% [markdown]
# ## Correlation

# %%
corr_mat = data.corr()
plt.figure(figsize=[22,16])
sns.heatmap(corr_mat,annot = True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
#     There are both positively and negatively correlated columns with the target column. With target - RA, ERA and ER are highly negatively correlated.
#     99% of correlation is between RA and ER,ERA. Since, there is less no. of data, we consider only 99% correlation.
#     Confirm whether correlation exists
# ## Confirming the correlation existence

# %%
plt.scatter(data.ERA, data.RA)
plt.xlabel('Earned Run Average')
plt.ylabel('Runs Allowed')
plt.title ('ERA vs RA')
plt.show()

# %% [markdown]
# Yes, it shows that Earned Run average and Runs Allowed are very highly correlated.

# %%
plt.scatter(data.ER, data.RA)
plt.xlabel('Earned Runs')
plt.ylabel('Runs Allowed')
plt.title ('ER vs RA')
plt.show()

# %% [markdown]
# Yes, it shows that Earned Runs and Runs Allowed are very highly correlated. So, remove Runs Allowed column

# %%
data = data.drop(['RA'],axis = 1)

# %% [markdown]
# Dropped Runs Earned, because it is highly correlated with ERA

# %% [markdown]
# ## Collinearity

# %%
data_corr = data.corr().abs()
plt.figure (figsize = (22,16))
sns.heatmap(data_corr,annot = True, annot_kws = {'size':8}) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There is collinearity observed between ER and ERA

# %%
data = data.drop(['ER'],axis = 1)

# %% [markdown]
# Drop ER column since the collinearity is high

# %% [markdown]
# ## Data Distribution

# %%
plt.figure(figsize = (20,20), facecolor = 'white')
plotnumber = 1

for column in data:
    if plotnumber <=16:
        ax =  plt.subplot(4,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize = 20)
    plotnumber+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - W looks normally distributed
# - R looks normally distributed with little skewness
# - AB looks normally distributed
# - H looks normally distributed
# - 2B looks normally distributed
# - 3B looks normally distributed
# - HR looks normally distributed
# - SO looks normally distributed
# - SB looks normally distributed
# - ERA looks normally distributed with little skewness
# - CG looks normally distributed
# - SHO looks normally distributed with little skewness
# - SV looks normally distributed with little skewness
# - E looks normally distributed with little skewness

# %% [markdown]
# ## Treating Outliers

# %%
plt.figure(figsize=(10,15))
graph = 1
for column in data:
    if graph<=16:
        ax = plt.subplot(4,4,graph)
        sns.boxplot(data[column],orient = 'V')
        plt.xlabel(column, fontsize=10)
    graph+=1
plt.show()

# %% [markdown]
# R, ERA, SHO,SV and E has outliers

# %% [markdown]
# ### Quantifying

# %%
from scipy.stats import zscore

# %%
x = data.drop('W',axis=1)
y = data['W']

# %% [markdown]
# Data is split into target and labels

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
data['R_zscore'] = zscore(data['R'])
data['is_outlier'] = data['R_zscore'].apply(lambda x: x<=-3 or x>=3)
data[data['is_outlier']]
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB  ERA  CG  SHO  SV   E  \
# 5  93  891  5509  1480  308  17  232  570  1151  88  3.8   7   10  34  88
#
#    R_zscore  is_outlier
# 5  3.509647        True

# %% [markdown]
# 5th index has the zscore more than3.

# %%
data['ERA_zscore'] = zscore(data['ERA'])
data['is_outlier'] = data['ERA_zscore'].apply(lambda x: x<=-3 or x>=3)
data[data['is_outlier']]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, ERA, CG, SHO, SV, E, R_zscore, is_outlier, ERA_zscore]
# Index: []

# %% [markdown]
# No zscore is more or less than 3

# %%
data['SHO_zscore'] = zscore(data['SHO'])
data['is_outlier'] = data['SHO_zscore'].apply(lambda x: x<=-3 or x>=3)
data[data['is_outlier']]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, ERA, CG, SHO, SV, E, R_zscore, is_outlier, ERA_zscore, SHO_zscore]
# Index: []

# %% [markdown]
# No zscore is more or less than 3

# %%
data['SV_zscore'] = zscore(data['SV'])
data['is_outlier'] = data['SV_zscore'].apply(lambda x: x<=-3 or x>=3)
data[data['is_outlier']]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, ERA, CG, SHO, SV, E, R_zscore, is_outlier, ERA_zscore, SHO_zscore, SV_zscore]
# Index: []

# %% [markdown]
# No zscore is more or less than 3

# %%
data['E_zscore'] = zscore(data['E'])
data['is_outlier'] = data['E_zscore'].apply(lambda x: x<=-3 or x>=3)
data[data['is_outlier']]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, ERA, CG, SHO, SV, E, R_zscore, is_outlier, ERA_zscore, SHO_zscore, SV_zscore, E_zscore]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.drop([5],inplace=True)

# %% [markdown]
# No zscore is more or less than 3. Since one index has the outlier, check for skewness also.

# %% [markdown]
# ## Checking Skewness

# %%
data.skew()
# Out:
# W             0.119013
# R            -0.215364
# AB            0.169573
# H             0.783772
# 2B           -0.335304
# 3B            0.090124
# HR            0.450862
# BB            0.151193
# SO           -0.233815
# SB            0.494966
# ERA           0.016693
# CG            0.854980
# SHO           0.526943
# SV            0.627480
# E             0.840271
# R_zscore     -0.215364
# is_outlier    0.000000
# ERA_zscore    0.016693
# SHO_zscore    0.526943
# SV_zscore     0.627480
# E_zscore      0.840271
# dtype: float64

# %% [markdown]
# Sort and find whether skewness is found

# %%
data.skew().sort_values()
# Out:
# 2B           -0.335304
# SO           -0.233815
# R            -0.215364
# R_zscore     -0.215364
# is_outlier    0.000000
# ERA           0.016693
# ERA_zscore    0.016693
# 3B            0.090124
# W             0.119013
# BB            0.151193
# AB            0.169573
# HR            0.450862
# SB            0.494966
# SHO           0.526943
# SHO_zscore    0.526943
# SV            0.627480
# SV_zscore     0.627480
# H             0.783772
# E_zscore      0.840271
# E             0.840271
# CG            0.854980
# dtype: float64

# %% [markdown]
# There is no skewness

# %% [markdown]
# ## Model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# Importing necessary libraries needed

# %%
x = data.drop(columns = ['W'])
y = data['W']

# %% [markdown]
# ### Standardise the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %% [markdown]
# Data is standardised

# %%
regression = LinearRegression()

# %% [markdown]
# Instantiate LinearRegression

# %%
maxreg = 0 
maxrs = 0
for i in range(1,300):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20, random_state = i)
    LR = LinearRegression()
    LR.fit(x_train,y_train)
    acc = LR.score(x_test,y_test)
    if acc>maxreg:
        maxreg = acc
        maxrs = i
print('Best regression score is:',maxreg,'on Random State',maxrs)
# Out:
# Best regression score is: 0.9757542113274398 on Random State 47

# %% [markdown]
# Best regression score is 0.97 at 47 random state

# %%
x_train,x_test,y_train,y_test = train_test_split (x,y,test_size=0.20,random_state=47)

# %% [markdown]
# Check with all the models where we get good score

# %% [markdown]
# ## Linear Regression

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
lr = LR.score(x_test,y_test)
print('Regression Score:',lr)

y_pred = LR.predict(x_test)

mae = mean_absolute_error(y_test,y_pred)
print('Mean Absolute Error:',mae)

mse = mean_squared_error(y_test,y_pred)
print('Mean Squared Error:',mse)
# Out:
# Regression Score: 0.9757542113274398
# Mean Absolute Error: 1.5078082795897292
# Mean Squared Error: 3.060357325780938

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
dtt = dt.score(x_test,y_test)
print('Regression Score:',dtt)

y_pred = dt.predict(x_test)

mae = mean_absolute_error(y_test,y_pred)
print('Mean Absolute Error:',mae)

mse = mean_squared_error(y_test,y_pred)
print('Mean Squared Error:',mse)
# Out:
# Regression Score: 0.7161091549295775
# Mean Absolute Error: 5.5
# Mean Squared Error: 35.833333333333336

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_ = rfr.score(x_test,y_test)
print('Regression Score:',rfr_)

y_pred = rfr.predict(x_test)

mae = mean_absolute_error(y_test,y_pred)
print('Mean Absolute Error:',mae)

mse = mean_squared_error(y_test,y_pred)
print('Mean Squared Error:',mse)
# Out:
# Regression Score: 0.6798825704225356
# Mean Absolute Error: 5.583333333333331
# Mean Squared Error: 40.40593333333328

# %% [markdown]
# Linear Rgression is the best model for this dataset with Regression score is 0.94

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

sc = cross_val_score(LR,x,y,cv=5)
print('LR cvs:',sc.mean())

sc1 = cross_val_score(dt,x,y,cv=5)
print('DT cvs:',sc1.mean())

sc2 = cross_val_score(rfr,x,y,cv=5)
print('RFR cvs:',sc2.mean())
# Out:
# LR cvs: 0.2956162841694415
# DT cvs: -2.302685411148947
# RFR cvs: -0.5767616416612711

# %% [markdown]
# The cross validation score shows that Linear Regression model is underfitting. So, do regularisation
# ## Regularisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state': list(range(0,10)),'max_iter':[10000],'normalize':[False]}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

clf.best_params_
# Out:
# {'alpha': 1, 'max_iter': 10000, 'normalize': False, 'random_state': 0}

# %%
ls = Lasso(alpha=1,random_state=0,max_iter = 10000, normalize= False)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
print(lss)

cv_score = cross_val_score(ls,x,y,cv=5)
cv_mean = cv_score.mean()
print(cv_mean)
# Out:
# 0.9210987315872559
# 0.42687597024193435

# %% [markdown]
# The Lasso score is 0.92 and the CV score is 0.42

# %% [markdown]
# ## Ensemble

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn import metrics

ada=AdaBoostRegressor()
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = ada.predict(x_train)
accuracy1 = metrics.r2_score(y_train,y_pred)
print('Training score:',accuracy1)
y_pred_test = ada.predict(x_test)
accuracy2 = metrics.r2_score(y_test,y_pred_test)
print('Testing score:',accuracy2)
# Out:
# Training score: 0.9864966286465646
# Testing score: 0.7143558898031044

# %% [markdown]
# On ensembling, training score is 0.98 and testing score is 0.71

# %% [markdown]
# ## Hyper parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %% [markdown]
# Import necessary libraries

# %%
params = {'n_estimators': [40,47,49,50], 'learning_rate':[0.30,0.40,0.45],'loss' : ['exponential'],'random_state' : [0]} 
rnd_search = RandomizedSearchCV (AdaBoostRegressor(), cv = 5, param_distributions = params,n_iter = 10,n_jobs=1)
print(rnd_search.fit(x_train,y_train))
print('Best Estimator:', rnd_search.best_estimator_)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(), n_jobs=1,
#                    param_distributions={'learning_rate': [0.3, 0.4, 0.45],
#                                         'loss': ['exponential'],
#                                         'n_estimators': [40, 47, 49, 50],
#                                         'random_state': [0]})
# Best Estimator: AdaBoostRegressor(learning_rate=0.45, loss='exponential', n_estimators=49,
#                   random_state=0)

# %% [markdown]
# Check the best estimator and imply it

# %%
ada = AdaBoostRegressor(base_estimator = dt, learning_rate=0.45,n_estimators=49)
ada.fit(x_train,y_train)
y_pred = ada.predict(x_test)

print('Accuracy post tuning')
print(metrics.r2_score(y_test,y_pred))
# Out:
# Accuracy post tuning
# 0.6685739436619719

# %% [markdown]
# Accuracy post tuning the parameters is 0.66. Since there was difference in Linear score and its CV value, save AdaBoostRegressor value to predict further

# %% [markdown]
# ## Save the model

# %%
import joblib
joblib.dump(ada,'BaseballCasestudy_Model.pkl')
# Out:
# ['BaseballCasestudy_Model.pkl']

# %% [markdown]
# Thus the model is saved
